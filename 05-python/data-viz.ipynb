# %% [markdown]
# ## Key Tips for your Data Visualization
# #### - **Create your vizzes with a purpose**
#     - Presentation (highlight a trend, show an outlier, help draw your conclusion)
#     - Analysis (personal work)
#     - Data visualization should be audience-specific with a clear requirement
#
# - **Chose the right type of chart**. The chart that best illustrates the narrative
# - **Keep it simple.** Remove clutter (Any dimentionality you are using, work to serve that purpose)
# - **Label your vizzes!** Graphs/Charts should have (descriptive title, axis titles (with units), proper format, consistent style)
# - **Clear** (high resolution, proper Aspect Ratio)
# - **Ditch the pie.** Pie charts seem friendly, but in reality they’re hard to read. In most cases, you can find a better alternative.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlp
import plotly.express as px
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
#!pip install plotly

# %%
sns.set(font_scale=1.5)

plt.style.use('ggplot')

from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 8, 4

# %%
churn = pd.read_csv('data/churn.csv')
mtcars = pd.read_csv('data/mtcars.csv')

# %%
mtcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
mtcars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
plt.scatter(mtcars['wt'], mtcars['mpg'], alpha=0.90)
plt.title('My Scatter Plot')
plt.xlabel('Weight (1000lb)')
plt.ylabel('Mileage (miles per gallon)')
plt.show()

# %%
plt.scatter(mtcars["wt"], mtcars["mpg"], alpha=0.65)
plt.title('A basic scatter plot')
plt.xlabel('weight')
plt.ylabel('miles per gallon')
# plt.rcParams.update({'text.color' : "red",
#                      'axes.labelcolor' : "red", 
#                      'xtick.color':"red",
#                      'ytick.color':"red"})
plt.show()

# %%
plt.bar(mtcars["cyl"], mtcars['disp'])
plt.title('mtcars cyl vs disp')
plt.xlabel('xlabel here')
plt.show();

# %%
# Create a Figure and an Axes with plt.subplots
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True)
print(ax.shape)
# Make plot
#> (3,)
for key, value in enumerate(mtcars["cyl"].unique()):
    ax[key].scatter(mtcars["wt"][mtcars["cyl"] == value],
     mtcars["mpg"][mtcars["cyl"] == value],
     alpha=0.65)

# Call the show function
plt.show()
# Out:
# (3,)

# %%
sns.scatterplot(x = mtcars["wt"], y = mtcars["mpg"])
# plt.rcParams.update({'text.color' : "black",
#                      'axes.labelcolor' : "black", 
#                      'xtick.color':"black",
#                      'ytick.color':"black"})
# Out:
# <AxesSubplot:xlabel='wt', ylabel='mpg'>

# %%
sns.scatterplot(x = mtcars["wt"], y = mtcars["mpg"], data = mtcars);
# Alternatively, using pandas Series:
# sns.scatterplot(mtcars["wt"], mtcars["mpg"])

# %%
sns.scatterplot(x="wt", y="mpg", hue="cyl", data = mtcars);

# %%
mtcars = mtcars.astype({"cyl": 'category'})
#mtcars = mtcars.astype({"cyl": 'category'})
sns.scatterplot(x="wt", y="mpg", hue="cyl", data = mtcars);

# %%
sns.scatterplot(x='wt', y='mpg', hue='cyl',
 palette=['#fc9272', '#ef3b2c', '#a50f15'], data = mtcars);

# %%
sns.scatterplot(x='wt', y='mpg', hue='cyl',
 size='disp', palette=['#fc9272', '#ef3b2c', '#a50f15'], data = mtcars);

print('Explain in details what this figure is telling us')
# Out:
# Explain in details what this figure is telling us

# %%
sns.barplot(x="cyl", y="wt", hue="am", data=mtcars);

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
mtcars.head()
# Out:
#                model   mpg cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0   6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0   6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8   4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4   6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example planets dataset
# planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=mtcars,
    x="wt", y="disp",
    hue="carb", size="cyl",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True);

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    mtcars,
    x="wt", hue="cyl",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.8,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([1, 20]);

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")

x = mtcars['wt']
y = mtcars['disp']

sns.jointplot(x=x, y=y, kind="scatter", color="#4CB391");

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France     NaN   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0       10134888.0       1
# 1       11254258.0       0
# 2       11393157.0       1
# 3              0.0       0
# ...

# %%
x = churn['Age']
y = churn['CreditScore']

sns.jointplot(x=x, y=y, kind="scatter", color="#4CB391", alpha=0.2);

# %%
# y = churn['Age']
# x = churn['Gender']

sns.violinplot(data=churn, y="Age", x= "Gender",
 hue="Gender", split=True);

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp", size="pop", color="continent",
           hover_name="country", log_x=True, size_max=75)
fig.show()
# Out:
# <div>                            <div id="593d75e4-bce5-4719-9310-6fe2791dcb78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("593d75e4-bce5-4719-9310-6fe2791dcb78")) {                    Plotly.newPlot(                        "593d75e4-bce5-4719-9310-6fe2791dcb78",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thaila
# ...

# %%
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=45, range_x=[100,100000], range_y=[25,90])
fig.show()
# Out:
# <div>                            <div id="8b202e8b-baff-4c16-b13e-c69e11939ea7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b202e8b-baff-4c16-b13e-c69e11939ea7")) {                    Plotly.newPlot(                        "8b202e8b-baff-4c16-b13e-c69e11939ea7",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Ta
# ...

# %% [markdown]
# ### Check the Documentations and gallery of examples of some of the popular libraries

# %% [markdown]
# - matplotlib: https://matplotlib.org/stable/gallery/index#
# - seaborn: http://seaborn.pydata.org/examples/
# - plotly: https://plotly.com/python/
# - plotnine (ggplot2 in python): https://plotnine.readthedocs.io/en/stable/gallery.html
# - dash: https://dash.gallery/Portal/
# - bokeh: https://docs.bokeh.org/en/latest/docs/gallery.html
# - Folium: https://python-visualization.github.io/folium/quickstart.html

# %% [markdown]
# ### Refrences used and resources for improving your data visualizations!
# - https://www.geckoboard.com/best-practice/data-visualization-tips/
# - https://blog.csgsolutions.com/6-tips-for-creating-effective-data-visualizations
# - https://uxplanet.org/12-tips-to-design-better-data-visualization-c7740a4da5e1
